# %% [markdown]
# Introduction to the Spotify Musical Popularity Prediction System.
#
# Business Understanding:
#
# Many music related businesses and services, including record labels (Rough
# Trade, EMI, Matador, etc.), music reviewing publications (Pitchfork, Stereogum,
# Consequence of sound, etc.), radio stations (KEXP, NPR, The Current, KCRW,
# etc.), rely on music curation and playlist creation, as a means to establish their
# presence or artists presence in their respective music scene. A music related
# company that delivers popular playlists with songs that appeal to a broad range
# of listeners is more likely to succeed than a music related company that does not.
# I am looking to see if it is possible to create a music recommendation system, to
# help these businesses choose the best songs/sounds/genres to apply to their
# playlists to achieve maximum visibility and exposure, either to their publications.
# Radio stations, and record labels/artists.

# %%
#Imports (Will import neccessary packages as the progress progresses)
import pandas as pd

# %% [markdown]
# Data Importing and Basic Analysis

# %%
#Importing spotify data set found from Kaggle, which contains over 230,000 songs, along with their attributes.

df = pd.read_csv('SpotifyFeatures.csv')
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
#viewing the individual statistics of each column in the data set
df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# 25%         0.385000          0.000000       0.097400     -11.771000
# 50%         0.605000          0.000044       0.128000      -7.762000
# 75%         0.787000          0.035800       0.264000      -5.501000
# max         0.999000          0.999000       1.000000       3.744000
#
#          speechiness          tempo        valence
# count  232725.000000  232725.000000  232725.000000
# mean        0.120765     117.666585       0.454917
# std         0.185518      30.898907       0.260065
# min         0.022200      30.379000       0.000000
# 25%         0.036700      92.959000       0.237000
# 50%         0.050100     115.778000       0.444000
# 75%         0.105000     139.054000       0.660000
# max         0.967000     242.903000       1.000000

# %%
#Viewing the data with their categorical and numerical information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB

# %%
#Viewing the various values contained within each of the columns
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts())
    print("--------------------")
# Out:
# Column: genre
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: genre, dtype: int64
# --------------------
# Column: artist_name
# Giuseppe Verdi            1394
# Giacomo Puccini           1137
# Kimbo Children's Music     971
# Nobuo Uematsu              825
# Richard Wagner             804
#                           ...
# Tom O'Connor                 1
# Yung Fume                    1
# SF9                          1
# Veronica Ra'elle             1
# Zonnique                     1
# Name: artist_name, Length: 14564, dtype: int64
# --------------------
# Column: track_name
# Home                                                                             100
# You                                                                               71
# Intro                                                                             69
# Stay                                                                              63
# Wake Up                                                                           59
#                                                                                 ...
# Once Again (Outra Vez)                                                             1
# Akai Wana (Who Loves It?) - Instrumental                                           1
# La Fanciulla del West, Act III: "Risparmiate lo scherno ... Ch'ella mi creda"      1
# Main Theme - Live / From Rain Man                                                  1
# Blue Lester                                                                        1
# Name: track_name, Length: 148615, dtype: int64
# --------------------
# Column: track_id
# 6sVQNUvcVFTXvlk3ec0ngd    8
# 0UE0RhnRaEYsiYgXpyLoZc    8
# 6AIte2Iej1QKlaofpjCzW1    8
# 0wY9rA9fJkuESyYm9uzVK5    8
# 3uSSjnDMmoyERaAK9KvpJR    8
#                          ..
# 6Vigp41BietH0WoFZ52JI5    1
# 7zXzTfMZ310Qb5QQfyfJ3b    1
# 56pKYnSA0CyayMJWcEU5kH    1
# 2haqQhsi8AM7mCpYPIr5mm    1
# 71DYyAwXEYLEDkdIbdwisk    1
# Name: track_id, Length: 176774, dtype: int64
# --------------------
# Column: popularity
# 0      6312
# 50     5415
# 53     5414
# 51     5401
# 52     5342
#        ...
# 96        8
# 94        7
# 99        4
# 98        3
# 100       2
# Name: popularity, Length: 101, dtype: int64
# --------------------
# Column: acousticness
# 0.995000    851
# 0.994000    701
# 0.992000    682
# 0.993000    646
# 0.991000    597
#            ...
# 0.000005      1
# 0.000007      1
# 0.000098      1
# 0.000083      1
# 0.000009      1
# Name: acousticness, Length: 4734, dtype: int64
# --------------------
# Column: danceability
# 0.5970    558
# 0.5470    544
# 0.6100    542
# 0.5890    542
# 0.6220    540
#          ...
# 0.0584      1
# 0.0577      1
# 0.0570      1
# 0.0878      1
# 0.0596      1
# Name: danceability, Length: 1295, dtype: int64
# --------------------
# Column: duration_ms
# 240000    138
# 180000    120
# 192000    115
# 216000     99
# 200000     85
#          ...
# 258851      1
# 238377      1
# 164064      1
# 244522      1
# 262144      1
# Name: duration_ms, Length: 70749, dtype: int64
# --------------------
# Column: energy
# 0.721000    417
# 0.675000    403
# 0.720000    392
# 0.686000    389
# 0.738000    389
#            ...
# 0.002230      1
# 0.000216      1
# 0.006110      1
# 0.009910      1
# 0.007330      1
# Name: energy, Length: 2517, dtype: int64
# --------------------
# Column: instrumentalness
# 0.00000    79236
# 0.91200      235
# 0.91000      230
# 0.91800      222
# 0.92300      222
#            ...
# 0.00966        1
# 0.99900        1
# 0.00667        1
# 0.99800        1
# 0.00888        1
# Name: instrumentalness, Length: 5400, dtype: int64
# --------------------
# Column: key
# C     27583
# G     26390
# D     24077
# C#    23201
# A     22671
# F     20279
# B     17661
# E     17390
# A#    15526
# F#    15222
# G#    15159
# D#     7566
# Name: key, dtype: int64
# --------------------
# Column: liveness
# 0.1110    2860
# 0.1100    2702
# 0.1080    2608
# 0.1090    2537
# 0.1070    2451
#           ...
# 0.0240       1
# 0.0185       1
# 0.0200       1
# 0.0177       1
# 0.0143       1
# Name: liveness, Length: 1732, dtype: int64
# --------------------
# Column: loudness
# -5.318     57
# -5.460     52
# -5.131     51
# -5.428     51
# -6.611     50
#            ..
# -31.696     1
# -38.267     1
# -45.192     1
# -28.588     1
# -1.494      1
# Name: loudness, Length: 27923, dtype: int64
# --------------------
# Column: mode
# Major    151744
# Minor     80981
# Name: mode, dtype: int64
# --------------------
# Column: speechiness
# 0.0374    663
# 0.0332    654
# 0.0337    652
# 0.0363    650
# 0.0343    642
#          ...
# 0.6070      1
# 0.6880      1
# 0.6620      1
# 0.6750      1
# 0.6670      1
# Name: speechiness, Length: 1641, dtype: int64
# --------------------
# Column: tempo
# 120.016    61
# 100.003    60
# 100.014    60
# 120.008    59
# 120.003    59
#            ..
# 82.571      1
# 94.596      1
# 62.067      1
# 91.555      1
# 110.206     1
# Name: tempo, Length: 78512, dtype: int64
# --------------------
# Column: time_signature
# 4/4    200760
# 3/4     24111
# 5/4      5238
# 1/4      2608
# 0/4         8
# Name: time_signature, dtype: int64
# --------------------
# Column: valence
# 0.9610    479
# 0.9620    403
# 0.9630    368
# 0.3700    363
# 0.3580    363
#          ...
# 0.0232      1
# 0.0209      1
# 0.9950      1
# 0.0227      1
# 0.0180      1
# Name: valence, Length: 1692, dtype: int64
# --------------------

# %%
#Above, I found some things that will need to be considered when doing my analysis and modeling.
#There is duplicative information in the dataset, one of them is the genre "Children's Music", and another is the duplicated values in the track_id column

# %% [markdown]
# DATA CLEANING: SCRUBBING

# %%
#The first bit of cleaning that I will be doing will be in regard to the duplicative "Children's Music" genre.As seen in the below code and output:
df['genre'].value_counts()
# Out:
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: genre, dtype: int64

# %%
#Since we have 2 different genres called "Children's Music", I am going to have to merge them both together so that the data can be consistent
df.loc[df['genre']=="Children’s Music",'genre']="Children's Music"

# %%
#Double Checking to make sure the merge has successfully occurred
df['genre'].value_counts()
# Out:
# Children's Music    14756
# Comedy               9681
# Soundtrack           9646
# Indie                9543
# Jazz                 9441
# Pop                  9386
# Electronic           9377
# Folk                 9299
# Hip-Hop              9295
# Rock                 9272
# Alternative          9263
# Classical            9256
# Rap                  9232
# World                9096
# Soul                 9089
# Blues                9023
# R&B                  8992
# Anime                8936
# Reggaeton            8927
# Ska                  8874
# Reggae               8771
# Dance                8701
# Country              8664
# Opera                8280
# Movie                7806
# A Capella             119
# Name: genre, dtype: int64

# %%
#Now that I have merged the duplicative genres together, I am going to check for Missing Values
df.isna().sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
#Since there are no missing values, I will be moving on to the other issue, which is the duplicated tracks portion.
df[df['track_id'].duplicated()]
# Out:
#               genre   artist_name  \
# 1348    Alternative      Doja Cat
# 1385    Alternative   Frank Ocean
# 1452    Alternative   Frank Ocean
# 1554    Alternative    Steve Lacy
# 1634    Alternative      tobi lou
# ...             ...           ...
# 232715         Soul    Emily King
# 232718         Soul  Muddy Waters
# 232720         Soul         Slave
# 232722         Soul  Muddy Waters
# 232723         Soul       R.LUM.R
#
#                                                track_name  \
# 1348                                           Go To Town
# 1385                                            Seigfried
# 1452                                         Bad Religion
# 1554                                                 Some
# 1634                                            Buff Baby
# ...                                                   ...
# 232715                                               Down
# 232718  I Just Want To Make Love To You - Electric Mud...
# 232720                                       Son Of Slide
# 232722                     (I'm Your) Hoochie Coochie Man
# 232723                                      With My Words
#
#                       track_id  popularity  acousticness  danceability  \
# 1348    6iOvnACn4ChlAw4lWUU4dd          64       0.07160         0.710
# 1385    1BViPjTT585XAhkUUrkts0          61       0.97500         0.377
# 1452    2pMPWE7PJH1PizfgGRMnR9          56       0.77900         0.276
# 1554    4riDfclV7kPDT9D58FpmHd          58       0.00548         0.784
# 1634    1F1QmI8TMHir9SUFrooq5F          59       0.19000         0.736
# ...                        ...         ...           ...           ...
# 232715  5cA0vB8c9FMOVDWyJHgf26          42       0.55000         0.394
# 232718  2HFczeynfKGiM9KF2z2K7K          43       0.01360         0.294
# 232720  2XGLdVl7lGeq8ksM6Al7jT          39       0.00384         0.687
# 232722  2ziWXUmQLrXTiYjCg2fZ2t          47       0.90100         0.517
# 232723  6EFsue2YbIG4Qkq8Zr9Rir          44       0.26200         0.745
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 1348         217813   0.710          0.000001   C    0.2060    -2.474  Major
# 1385         334570   0.255          0.000208   E    0.1020   -11.165  Minor
# 1452         175453   0.358          0.000003   A    0.0728    -7.684  Major
# 1554         118393   0.554          0.254000   G    0.0995    -6.417  Major
# 1634         215385   0.643          0.000000   F    0.1060    -8.636  Major
# ...             ...     ...               ...  ..       ...       ...    ...
# 232715       281853   0.346          0.000002   E    0.1290   -13.617  Major
# 232718       258267   0.739          0.004820   C    0.1380    -7.167  Major
# 232720       326240   0.714          0.544000   D    0.0845   -10.626  Major
# 232722       166960   0.419          0.000000   D    0.0945    -8.282  Major
# 232723       222442   0.704          0.000000   A    0.3330    -7.137  Major
#
#         speechiness    tempo time_signature  valence
# 1348         0.0579  169.944            4/4    0.700
# 1385         0.0387  125.004            5/4    0.370
# 1452         0.0443   81.977            4/4    0.130
# 1554         0.0300  104.010            4/4    0.634
# 1634         0.0461  156.002            4/4    0.599
# ...             ...      ...            ...      ...
# 232715       0.0635   90.831            4/4    0.436
# 232718       0.0434  176.402            4/4    0.945
# 232720       0.0316  115.542            4/4    0.962
# 232722       0.1480   84.135            4/4    0.813
# 232723       0.1460  100.031            4/4    0.489
#
# [55951 rows x 18 columns]

# %%
#As seen above, there is 55,951 duplicative rows of data. Before I fix this, I will need to look at the cause of the duplication.
#I start by checking rows for duplicated ids to see differences. I will do this for a few different tracks for consistency purposes.
df[df['track_id']=='2pMPWE7PJH1PizfgGRMnR9']
# Out:
#                    genre  artist_name    track_name                track_id  \
# 277                  R&B  Frank Ocean  Bad Religion  2pMPWE7PJH1PizfgGRMnR9
# 1452         Alternative  Frank Ocean  Bad Religion  2pMPWE7PJH1PizfgGRMnR9
# 68864            Hip-Hop  Frank Ocean  Bad Religion  2pMPWE7PJH1PizfgGRMnR9
# 77707   Children's Music  Frank Ocean  Bad Religion  2pMPWE7PJH1PizfgGRMnR9
# 192203              Soul  Frank Ocean  Bad Religion  2pMPWE7PJH1PizfgGRMnR9
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 277             61         0.779         0.276       175453   0.358
# 1452            56         0.779         0.276       175453   0.358
# 68864           61         0.779         0.276       175453   0.358
# 77707           61         0.779         0.276       175453   0.358
# 192203          61         0.779         0.276       175453   0.358
#
#         instrumentalness key  liveness  loudness   mode  speechiness   tempo  \
# 277             0.000003   A    0.0728    -7.684  Major       0.0443  81.977
# 1452            0.000003   A    0.0728    -7.684  Major       0.0443  81.977
# 68864           0.000003   A    0.0728    -7.684  Major       0.0443  81.977
# 77707           0.000003   A    0.0728    -7.684  Major       0.0443  81.977
# 192203          0.000003   A    0.0728    -7.684  Major       0.0443  81.977
#
#        time_signature  valence
# 277               4/4     0.13
# 1452              4/4     0.13
# 68864             4/4     0.13
# 77707             4/4     0.13
# 192203            4/4     0.13

# %%
df[df['track_id']=='2XGLdVl7lGeq8ksM6Al7jT']
# Out:
#        genre artist_name    track_name                track_id  popularity  \
# 179212  Jazz       Slave  Son Of Slide  2XGLdVl7lGeq8ksM6Al7jT          39
# 232720  Soul       Slave  Son Of Slide  2XGLdVl7lGeq8ksM6Al7jT          39
#
#         acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 179212       0.00384         0.687       326240   0.714             0.544   D
# 232720       0.00384         0.687       326240   0.714             0.544   D
#
#         liveness  loudness   mode  speechiness    tempo time_signature  \
# 179212    0.0845   -10.626  Major       0.0316  115.542            4/4
# 232720    0.0845   -10.626  Major       0.0316  115.542            4/4
#
#         valence
# 179212    0.962
# 232720    0.962

# %%
#As seen in the two different code blocks, most of the attributes for the songs with duplicative values are consistent, with the exception of the values 'popularity' and 'genre'
#To combat this issue, I researched that the best way was to create different columns with genre names, and having binary values represent whether or not certain songs belong in a certain genre.

# %%
#Step one in this process is creating a list with the genre names
genre_list = list(df['genre'].unique())

# %%
#Next is creating the genre columns using this new genre list
for genre in genre_list:
    df[genre] = (df['genre']==genre).astype('int')

# %%
#Next is grouping each of the tracks by track_id to cleanse the dataset of duplicates, and ensure that the maximum values stay the same in each of the columns.
df=df.groupby(['track_id']).max()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1049             try:
# -> 1050                 result, _ = self.grouper.aggregate(
#    1051                     block.values, how, axis=1, min_count=min_count
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\ops.py in aggregate(self, values, how, axis, min_count)
#     583     ) -> Tuple[np.ndarray, Optional[List[str]]]:
# --> 584         return self._cython_operation(
#     585             "aggregate", values, how, axis, min_count=min_count
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     519
# --> 520         func, values = self._get_cython_func_and_vals(kind, how, values, is_numeric)
#     521
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_func_and_vals(self, kind, how, values, is_numeric)
#     420         try:
# --> 421             func = self._get_cython_function(kind, how, values, is_numeric)
#     422         except NotImplementedError:
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_function(self, kind, how, values, is_numeric)
#     394         if func is None:
# --> 395             raise NotImplementedError(
#     396                 f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->max,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-2ecedd4d7ff0> in <module>
#       1 #Next is grouping each of the tracks by track_id to cleanse the dataset of duplicates, and ensure that the maximum values stay the same in each of the columns.
# ----> 2 df=df.groupby(['track_id']).max()
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in max(self, numeric_only, min_count)
#    1555     @doc(_groupby_agg_method_template, fname="max", no=False, mc=-1)
#    1556     def max(self, numeric_only: bool = False, min_count: int = -1):
# -> 1557         return self._agg_general(
#    1558             numeric_only=numeric_only, min_count=min_count, alias="max", npfunc=np.max
#    1559         )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     997         # try a cython aggregation if we can
#     998         try:
# --> 999             return self._cython_agg_general(
#    1000                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1001             )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1019         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1020     ) -> DataFrame:
# -> 1021         agg_blocks, agg_items = self._cython_agg_blocks(
#    1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1023         )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1076                 s = get_groupby(obj, self.grouper, observed=True)
#    1077                 try:
# -> 1078                     result = s.aggregate(lambda x: alt(x, axis=self.axis))
#    1079                 except TypeError:
#    1080                     # we may have an exception in trying to aggregate
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     258
#     259             try:
# --> 260                 return self._python_agg_general(
#     261                     func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     262                 )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, engine, engine_kwargs, *args, **kwargs)
#    1081                 try:
#    1082                     # if this function is invalid for this dtype, we will ignore it.
# -> 1083                     result, counts = self.grouper.agg_series(obj, f)
#    1084                 except TypeError:
#    1085                     continue
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func, engine, engine_kwargs, *args, **kwargs)
#     642
#     643         try:
# --> 644             return self._aggregate_series_fast(obj, func)
#     645         except ValueError as err:
#     646             if "Function does not reduce" in str(err):
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     667         group_index = algorithms.take_nd(group_index, indexer, allow_fill=False)
#     668         grouper = libreduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 669         result, counts = grouper.get_result()
#     670         return result, counts
#     671
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1058         func = self._is_builtin_func(func)
#    1059         if engine != "numba":
# -> 1060             f = lambda x: func(x, *args, **kwargs)
#    1061
#    1062         # iterate through "columns" ex exclusions to populate output dict
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\generic.py in <lambda>(x)
#    1076                 s = get_groupby(obj, self.grouper, observed=True)
#    1077                 try:
# -> 1078                     result = s.aggregate(lambda x: alt(x, axis=self.axis))
#    1079                 except TypeError:
#    1080                     # we may have an exception in trying to aggregate
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2665     5
#    2666     """
# -> 2667     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2668                           keepdims=keepdims, initial=initial, where=where)
#    2669
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      87             else:
# ---> 88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
#      90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in reduction(values, axis, skipna, mask)
#     860     ) -> Dtype:
#     861
# --> 862         values, mask, dtype, dtype_max, fill_value = _get_values(
#     863             values, skipna, fill_value_typ=fill_value_typ, mask=mask
#     864         )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     284     values = extract_array(values, extract_numpy=True)
#     285
# --> 286     mask = _maybe_get_mask(values, skipna, mask)
#     287
#     288     dtype = values.dtype
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in _maybe_get_mask(values, skipna, mask)
#     230
#     231         if skipna:
# --> 232             mask = isna(values)
#     233
#     234     return mask
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     122     Name: 1, dtype: bool
#     123     """
# --> 124     return _isna(obj)
#     125
#     126
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\dtypes\missing.py in _isna(obj, inf_as_na)
#     155         return False
#     156     elif isinstance(obj, (ABCSeries, np.ndarray, ABCIndexClass, ABCExtensionArray)):
# --> 157         return _isna_ndarraylike(obj, inf_as_na=inf_as_na)
#     158     elif isinstance(obj, ABCDataFrame):
#     159         return obj.isna()
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj, inf_as_na)
#     216             result = values.isna()
#     217     elif is_string_dtype(dtype):
# --> 218         result = _isna_string_dtype(values, dtype, inf_as_na=inf_as_na)
#     219     elif needs_i8_conversion(dtype):
#     220         # this is the NaT pattern
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\dtypes\missing.py in _isna_string_dtype(values, dtype, inf_as_na)
#     248             vec = libmissing.isnaobj(values.ravel())
#     249
# --> 250         result[...] = vec.reshape(shape)
#     251
#     252     return result
#
# KeyboardInterrupt:

# %%
#removing redundant genre column
df.drop('genre', axis=1, inplace=True)
df.head()
# Out:
#                               artist_name                          track_name  \
# track_id
# 00021Wy6AyMbLP2tqij86e  Capcom Sound Team                     Zangief's Theme
# 000CzNKC8PEt1yC3L8dqwV     Henri Salvador  Coeur Brisé à Prendre - Remastered
# 000DfZJww8KiixTKuk9usJ          Mike Love                          Earthlings
# 000EWWBkYaREzsBplYjUag       Don Philippe                           Fewerdolr
# 000xQL6tZNLJzIrtIgxqSl               ZAYN                      Still Got Time
#
#                         popularity  acousticness  danceability  duration_ms  \
# track_id
# 00021Wy6AyMbLP2tqij86e          13         0.234         0.617       169173
# 000CzNKC8PEt1yC3L8dqwV           5         0.249         0.518       130653
# 000DfZJww8KiixTKuk9usJ          30         0.366         0.631       357573
# 000EWWBkYaREzsBplYjUag          39         0.815         0.768       104924
# 000xQL6tZNLJzIrtIgxqSl          70         0.131         0.748       188491
#
#                         energy  instrumentalness key  liveness  ...  Pop  \
# track_id                                                        ...
# 00021Wy6AyMbLP2tqij86e   0.862          0.976000   G    0.1410  ...    0
# 000CzNKC8PEt1yC3L8dqwV   0.805          0.000000   F    0.3330  ...    0
# 000DfZJww8KiixTKuk9usJ   0.513          0.000004   D    0.1090  ...    0
# 000EWWBkYaREzsBplYjUag   0.137          0.922000  C#    0.1130  ...    0
# 000xQL6tZNLJzIrtIgxqSl   0.627          0.000000   G    0.0852  ...    1
#
#                        Reggae  Reggaeton  Jazz Rock  Ska  Comedy  Soul  \
# track_id
# 00021Wy6AyMbLP2tqij86e      0          0     0    0    0       0     0
# 000CzNKC8PEt1yC3L8dqwV      0          0     0    0    0       0     0
# 000DfZJww8KiixTKuk9usJ      1          0     0    0    0       0     0
# 000EWWBkYaREzsBplYjUag      0          0     1    0    0       0     0
# 000xQL6tZNLJzIrtIgxqSl      0          0     0    0    0       0     0
#
#                         Soundtrack  World
# track_id
# 00021Wy6AyMbLP2tqij86e           0      0
# 000CzNKC8PEt1yC3L8dqwV           0      0
# 000DfZJww8KiixTKuk9usJ           0      0
# 000EWWBkYaREzsBplYjUag           0      0
# 000xQL6tZNLJzIrtIgxqSl           0      0
#
# [5 rows x 42 columns]
